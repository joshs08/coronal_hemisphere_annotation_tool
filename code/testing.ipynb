# %%
import numpy as np

ex = np.load("J:\CHAT\output_251030_new_midlines\2018-09-04\segmentation\exclude.npy")
print(ex)
print("W")
# Out:
# Running cells with 'chat_2 (Python 3.9.24)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n chat_2 ipykernel --update-deps --force-reinstall'
